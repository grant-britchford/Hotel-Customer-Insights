# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt

print(sys.version)

df = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [2, 3, 5, 7, 11]
})
display(df)
df.plot(x='x', y='y', kind='line')
plt.show()
# Out:
# 3.12.1 (main, Mar 11 2026, 12:17:56) [GCC 13.3.0]
#    x   y
# 0  1   2
# 1  2   3
# 2  3   5
# 3  4   7
# 4  5  11
